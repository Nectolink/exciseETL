# %%
## importing modules 

import dask.dataframe as dd
import cx_Oracle      as ora

# loading data for 2 - Wheeler 

df2Challan = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\2W\MVRDB_CHALLAN.csv' , 
                         dtype = { 'ADDITIONALAMOUNT': 'float64',
                                   'BRANCHNAME2'     : 'object' ,
                                   'BRANCHNAME3'     : 'object' ,
                                   'PODATE2'         : 'object' ,
                                   'PODATE3'         : 'object' ,
                                   'PONO'            : 'object' ,
                                   'PONO2'           : 'object' ,
                                   'SBPNO'           : 'object' ,
                                   'TERMINALGROUPID' : 'float64'})

df2AChallan                = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\2W\MVRDB_ARCHIVECHALLAN.csv'          )
df2ChargeSlab              = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\2W\MVRDB_CHARGESLAB.csv'              )
df2ChallanDetail           = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\2W\MVRDB_CHALLANDETAIL.csv'           )
df2AChallanDetail          = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\2W\MVRDB_ARCHIVECHALLANDETAIL.csv'    )
df2ODAChallan              = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\2W\MVRDB_ODARCHIVECHALLAN.csv'        )
df2ODAChallanDetail        = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\2W\MVRDB_ODARCHIVECHALLANDETAIL.csv'  )
df2Charge                  = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\2W\MVRDB_CHARGE.csv'                  )
df2ChargeType              = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\2W\MVRDB_CHARGETYPE.csv'              )
df2ChargeAssignVehicleType = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\2W\MVRDB_CHARGEASSIGNVEHICLETYPE.csv' )
df2VehicleCat              = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\2W\MVRDB_VEHICLECATEGORY.csv'         )


# loading data for 4 - Wheeler

df4Challan = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\4W\MVRDB_CHALLAN.csv' , 
                         dtype = { 'BANKID'         : 'float64',
                                   'BRANCHNAME3'    : 'object' ,
                                   'BRANCHNAME4'    : 'object' ,
                                   'LOGINID'        : 'float64',
                                   'PODATE3'        : 'object' ,
                                   'PODATE4'        : 'object' ,
                                   'PONO2'          : 'object' ,
                                   'PONO3'          : 'object' ,
                                   'PONO4'          : 'object' ,
                                   'REMARKS'        : 'object' ,
                                   'TERMINALGROUPID': 'float64',
                                   'TOTAL'          : 'float64',
                                   'USERDETAILID'   : 'float64'})

df4AChallan = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\4W\MVRDB_ARCHIVECHALLAN.csv' , 
                          dtype = { 'BANKID'         : 'float64',
                                    'BRANCHNAME3'    : 'object' ,
                                    'BRANCHNAME4'    : 'object' ,
                                    'LOGINID'        : 'float64',
                                    'PODATE3'        : 'object' ,
                                    'PODATE4'        : 'object' ,
                                    'PONO2'          : 'object' ,
                                    'PONO3'          : 'object' ,
                                    'PONO4'          : 'object' ,
                                    'REMARKS'        : 'object' ,
                                    'TERMINALGROUPID': 'float64',
                                    'TOTAL'          : 'float64',
                                    'USERDETAILID'   : 'float64'})

df4ChargeSlab = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\4W\MVRDB_CHARGESLAB.csv' , 
                            dtype = { 'CHARGEID'    : 'float64',
                                      'CHARGETYPEID': 'float64',
                                      'ISACTIVE'    : 'float64',
                                      'LOGINID'     : 'float64'})

df4ChallanDetail  = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\4W\MVRDB_CHALLANDETAIL.csv', 
                                dtype = { 'CHARGESLABID' : 'float64'})

df4AChallanDetail = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\4W\MVRDB_ARCHIVECHALLANDETAIL.csv' , 
                                dtype = { 'CHARGESLABID' : 'float64'})

df4ODAChallan              = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\4W\MVRDB_ODARCHIVECHALLAN.csv'        )
df4ODAChallanDetail        = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\4W\MVRDB_ODARCHIVECHALLANDETAIL.csv'  ) 
df4Charge                  = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\4W\MVRDB_CHARGE.csv'                  )
df4ChargeType              = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\4W\MVRDB_CHARGETYPE.csv'              )
df4ChargeAssignVehicleType = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\4W\MVRDB_CHARGEASSIGNVEHICLETYPE.csv' )
df4VehicleCat              = dd.read_csv(r'C:\Users\umair\Desktop\Excise BI\DataDump\4W\MVRDB_VEHICLECATEGORY.csv'         )


# Droping undesired Columns 

# for challan tables
df2Challan = df2Challan.drop([ 'CHALLANPATH' , 'PENWAIVEAUTH'     , 'REMARKS'        , 'PONO'            ,
                               'BRANCHNAME'  , 'LATEREGID'        , 'SBPNO'          , 'SBPDATE'         ,
                               'DESCRIPTION' , 'CHALLANSEQUENCES' , 'UPDATEDDATE'    , 'ISACTIVE'        ,
                               'LOGINID'     , 'PODATE'           , 'TEMPTERMINALID' , 'TERMINALGROUPID' ,
                               'BLOCK'       , 'PONO2'            , 'PONO3'          , 'PONO4'           ,
                               'POAMOUNT1'   , 'POAMOUNT2'        , 'POAMOUNT3'      , 'POAMOUNT4'       ,
                               'PODATE2'     , 'PODATE3'          , 'PODATE4'        , 'BRANCHNAME2'     ,
                               'BRANCHNAME3' , 'BRANCHNAME4'      , 'BANKID2'        , 'BANKID3'         ,
                               'BANKID4'     , 'MVRBRANCHID'      , 'OWNERID' ], axis = 1)
df4Challan = df4Challan.drop([ 'CHALLANPATH' , 'PENWAIVEAUTH'     , 'REMARKS'        , 'PONO'            ,
                               'BRANCHNAME'  , 'LATEREGID'        , 'SBPNO'          , 'SBPDATE'         ,
                               'DESCRIPTION' , 'CHALLANSEQUENCES' , 'UPDATEDDATE'    , 'ISACTIVE'        ,
                               'LOGINID'     , 'PODATE'           , 'TEMPTERMINALID' , 'TERMINALGROUPID' ,
                               'BLOCK'       , 'PONO2'            , 'PONO3'          , 'PONO4'           ,
                               'POAMOUNT1'   , 'POAMOUNT2'        , 'POAMOUNT3'      , 'POAMOUNT4'       ,
                               'PODATE2'     , 'PODATE3'          , 'PODATE4'        , 'BRANCHNAME2'     ,
                               'BRANCHNAME3' , 'BRANCHNAME4'      , 'BANKID2'        , 'BANKID3'         ,
                               'BANKID4'     , 'MVRBRANCHID'      , 'OWNERID' ], axis = 1)

df2AChallan = df2AChallan.drop([ 'CHALLANPATH' , 'PENWAIVEAUTH'     , 'REMARKS'         , 'PONO'           ,
                                 'BRANCHNAME'  , 'LATEREGID'        , 'SBPNO'           , 'SBPDATE'        ,
                                 'DESCRIPTION' , 'CHALLANSEQUENCES' , 'UPDATEDDATE'     , 'ISACTIVE'       ,
                                 'LOGINID'     , 'PODATE'           , 'TERMINALGROUPID' , 'PONO2'          ,
                                 'PONO3'       , 'PONO4'            , 'MVRBRANCHID'     , 'ARCHIVEOWNERID' ,
                                 'POAMOUNT1'   , 'POAMOUNT2'        , 'POAMOUNT3'       , 'POAMOUNT4'      ,
                                 'PODATE2'     , 'PODATE3'          , 'PODATE4'         , 'BRANCHNAME2'    ,
                                 'BRANCHNAME3' , 'BRANCHNAME4'      , 'BANKID2'         , 'BANKID3'        ,
                                 'BANKID4'     , 'DEALERINFOID' ], axis = 1)
df4AChallan = df4AChallan.drop([ 'CHALLANPATH' , 'PENWAIVEAUTH'     , 'REMARKS'         , 'PONO'           ,
                                 'BRANCHNAME'  , 'LATEREGID'        , 'SBPNO'           , 'SBPDATE'        ,
                                 'DESCRIPTION' , 'CHALLANSEQUENCES' , 'UPDATEDDATE'     , 'ISACTIVE'       ,
                                 'LOGINID'     , 'PODATE'           , 'TERMINALGROUPID' , 'PONO2'          ,
                                 'PONO3'       , 'PONO4'            , 'MVRBRANCHID'     , 'ARCHIVEOWNERID' ,
                                 'POAMOUNT1'   , 'POAMOUNT2'        , 'POAMOUNT3'       , 'POAMOUNT4'      ,
                                 'PODATE2'     , 'PODATE3'          , 'PODATE4'         , 'BRANCHNAME2'    ,
                                 'BRANCHNAME3' , 'BRANCHNAME4'      , 'BANKID2'         , 'BANKID3'        ,
                                 'BANKID4'     , 'DEALERINFOID' ], axis = 1)

df2ODAChallan = df2ODAChallan.drop([ 'CHALLANPATH' , 'PENWAIVEAUTH'     , 'REMARKS'         , 'PONO'             ,
                                     'BRANCHNAME'  , 'LATEREGID'        , 'SBPNO'           , 'SBPDATE'          ,
                                     'DESCRIPTION' , 'CHALLANSEQUENCES' , 'UPDATEDDATE'     , 'ISACTIVE'         ,
                                     'LOGINID'     , 'PODATE'           , 'TERMINALGROUPID' , 'PONO2'            ,
                                     'PONO3'       , 'PONO4'            , 'MVRBRANCHID'     , 'ODARCHIVEOWNERID' ,
                                     'POAMOUNT1'   , 'POAMOUNT2'        , 'POAMOUNT3'       , 'POAMOUNT4'        ,
                                     'PODATE2'     , 'PODATE3'          , 'PODATE4'         , 'BRANCHNAME2'      ,
                                     'BRANCHNAME3' , 'BRANCHNAME4'      , 'BANKID2'         , 'BANKID3'          ,
                                     'BANKID4'     , 'DEALERINFOID'     , 'PAYORDERAMOUNT2' , 'PAYORDERAMOUNT3' ], axis = 1)
df4ODAChallan = df4ODAChallan.drop([ 'CHALLANPATH' , 'PENWAIVEAUTH'     , 'REMARKS'         , 'PONO'             ,
                                     'BRANCHNAME'  , 'LATEREGID'        , 'SBPNO'           , 'SBPDATE'          ,
                                     'DESCRIPTION' , 'CHALLANSEQUENCES' , 'UPDATEDDATE'     , 'ISACTIVE'         ,
                                     'LOGINID'     , 'PODATE'           , 'TERMINALGROUPID' , 'PONO2'            ,
                                     'PONO3'       , 'PONO4'            , 'MVRBRANCHID'     , 'ODARCHIVEOWNERID' ,
                                     'POAMOUNT1'   , 'POAMOUNT2'        , 'POAMOUNT3'       , 'POAMOUNT4'        ,
                                     'PODATE2'     , 'PODATE3'          , 'PODATE4'         , 'BRANCHNAME2'      ,
                                     'BRANCHNAME3' , 'BRANCHNAME4'      , 'BANKID2'         , 'BANKID3'          ,
                                     'BANKID4'     , 'DEALERINFOID'     , 'PAYORDERAMOUNT2' , 'PAYORDERAMOUNT3' ], axis = 1)

# for challandetail tables 

df2ChallanDetail = df2ChallanDetail.drop([ 'UPDATEDDATE' , 'ISACTIVE' , 'LOGINID' ], axis = 1)
df4ChallanDetail = df4ChallanDetail.drop([ 'UPDATEDDATE' , 'ISACTIVE' , 'LOGINID' ], axis = 1)

df2AChallanDetail = df2AChallanDetail.drop([ 'UPDATEDDATE' , 'ISACTIVE' , 'LOGINID' ], axis = 1)
df4AChallanDetail = df4AChallanDetail.drop([ 'UPDATEDDATE' , 'ISACTIVE' , 'LOGINID' ], axis = 1)

df2ODAChallanDetail = df2ODAChallanDetail.drop([ 'UPDATEDDATE' , 'ISACTIVE' , 'LOGINID' ], axis = 1)
df4ODAChallanDetail = df4ODAChallanDetail.drop([ 'UPDATEDDATE' , 'ISACTIVE' , 'LOGINID' ], axis = 1)

# for ChargeSlab tables

df2ChargeSlab = df2ChargeSlab.drop([ 'UPDATEDDATE' , 'ISACTIVE' , 'LOGINID' , 'ISSEAT' ,
                                     'ISCC'        , 'ISMULTI'  , 'ISLOADING' ], axis = 1)
df4ChargeSlab = df4ChargeSlab.drop([ 'UPDATEDDATE' , 'ISACTIVE' , 'LOGINID' , 'ISSEAT' ,
                                     'ISCC'        , 'ISMULTI'  , 'ISLOADING' ], axis = 1)

# for Charge tables

df2Charge = df2Charge.drop([ 'UNLADENWEIGHTFROM' , 'UNLADENWEIGHTTO' , 'URGENTNORMAL' ,	'ISVALID'        ,
                             'UPDATEDDATE'       , 'ISACTIVE'        , 'LOGINID'	  , 'OLDVEHICLETYPE' ,	
                             'LOCALHIGHWAY'	     , 'CYCLEFOROLD'     , 'DESCRIPTION' ], axis =1)
df4Charge = df4Charge.drop([ 'UNLADENWEIGHTFROM' , 'UNLADENWEIGHTTO' , 'URGENTNORMAL' ,	'ISVALID'        ,
                             'UPDATEDDATE'       , 'ISACTIVE'        , 'LOGINID'	  , 'OLDVEHICLETYPE' ,	
                             'LOCALHIGHWAY'	     , 'CYCLEFOROLD'     , 'COPYID'       , 'DESCRIPTION' ], axis = 1)

# for Chagre Type Tables

df2ChargeType = df2ChargeType.drop([ 'ISPERCENT' , 'UPDATEDDATE' , 'ISACTIVE' , 'LOGINID' ], axis = 1)
df4ChargeType = df4ChargeType.drop([ 'ISPERCENT' , 'UPDATEDDATE' , 'ISACTIVE' , 'LOGINID' ], axis = 1)

# for Charge Assign Vehicle Type

df2ChargeAssignVehicleType = df2ChargeAssignVehicleType.drop([ 'ISACTIVE' , 'UPDATEDDATE' , 'LOGINID'], axis = 1)
df4ChargeAssignVehicleType = df4ChargeAssignVehicleType.drop([ 'ISACTIVE' , 'UPDATEDDATE' , 'LOGINID'], axis = 1)

# for Vehicle Category table

df2VehicleCat = df2VehicleCat.drop([ 'UPDATEDDATE' , 'ISACTIVE' , 'LOGINID' , 'ISCHOICE'] , axis = 1)
df4VehicleCat = df4VehicleCat.drop([ 'UPDATEDDATE' , 'ISACTIVE' , 'LOGINID' , 'ISCHOICE'] , axis = 1)

# cleaning data for charge table

df2Charge.VEHICLECATEGORYID = df2Charge.VEHICLECATEGORYID.fillna(value = 6)
df2Charge.VEHICLECATEGORYID = df2Charge.VEHICLECATEGORYID.astype('int64')

df4Charge.VEHICLECATEGORYID = df4Charge.VEHICLECATEGORYID.fillna(value = 6)
df4Charge.VEHICLECATEGORYID = df4Charge.VEHICLECATEGORYID.astype('int64')

# cleaning data for Vehicle Category table

df2VehicleCat.VEHICLECATEGORYID = df2VehicleCat.VEHICLECATEGORYID.astype('int64')
df4VehicleCat.VEHICLECATEGORYID = df4VehicleCat.VEHICLECATEGORYID.astype('int64')

# joining CHARGE and Vehicle Category tables 

df2VehicleCat = df2VehicleCat.set_index('VEHICLECATEGORYID')
df4VehicleCat = df4VehicleCat.set_index('VEHICLECATEGORYID')

Charge2 = df2Charge.join(df2VehicleCat , lsuffix = '_C' , rsuffix= '_VC' , how = 'left' , on = 'VEHICLECATEGORYID')
Charge4 = df4Charge.join(df4VehicleCat , lsuffix = '_C' , rsuffix= '_VC' , how = 'left' , on = 'VEHICLECATEGORYID')

# %%
Charge2.head(1000)
# Out:
# C:\Users\umair\Anaconda3\lib\site-packages\dask\dataframe\core.py:4206: UserWarning: Insufficient elements for `head`. 1000 elements requested, only 461 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
#      CHARGEID  TAXCLASS  VEHICLECATEGORYID  CYCLE  LOCALIMPORTED  SEATSFROM  \
# 0           1         1                  1      2              0          0
# 1           2         2                  1      2              0          5
# 2           3         3                  1      4              0          9
# 3           4         4                  1      2              0          0
# 4           5         5                  1      2              0          5
# 5           6         6                  1      2              0          9
# 6           7         7                  1      2              0          0
# 7           8         8                  1      2              0          5
# ...

# %%
Charge4.head()
# Out:
#    CHARGEID TAXCLASS  VEHICLECATEGORYID  CYCLE  LOCALIMPORTED  SEATSFROM  \
# 0         1      001                  1    4.0            0.0        0.0
# 1         2      002                  1    4.0            0.0        5.0
# 2         3      003                  1    4.0            0.0        9.0
# 3         4      004                  1    4.0            0.0        0.0
# 4         5      005                  1    4.0            0.0        5.0
#
#    SEATSTO  ENGINECAPACITYFROM  ENGINECAPACITYTO NAME  EXMPT
# 0      4.0                 0.0             999.0   PR    0.0
# 1      8.0               100.0             999.0   PR    0.0
# 2     10.0                 0.0             999.0   PR    0.0
# 3      4.0              1000.0            1000.0   PR    0.0
# 4      8.0              1000.0            1000.0   PR    0.0

# %%
df2VehicleCat.head(10)
# Out:
# C:\Users\umair\Anaconda3\lib\site-packages\dask\dataframe\core.py:4206: UserWarning: Insufficient elements for `head`. 10 elements requested, only 7 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
#                     NAME  EXMPT
# VEHICLECATEGORYID
# 1                     PR      0
# 2                     CR      0
# 3                     MC      0
# 4                     GR      0
# 5                     EX      1
# 6                  error      1
# 7                  Cover      1
